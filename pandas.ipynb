# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi-sreeji/Machine-Learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv


with open("/content/sample_data/movies.csv") as f:
  data=list(csv.reader(f))
  header=data[0]
  data=data[1:]
  print("data is",data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-14544ec3c9c6> in <cell line: 4>()
#       2
#       3
# ----> 4 with open("/content/sample_data/movies.csv") as f:
#       5   data=list(csv.reader(f))
#       6   header=data[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/movies.csv'

# %%
def calculate_rating_stats(data, industry=None):
     ratings = []
     for row in data:

      if row[3]!='NULL' and (not industry or row[1]==industry):
        ratings.append(float(row[3]))
     max_rating = max(ratings)
     min_rating = min(ratings)
     avg_rating = sum(ratings) / len(ratings)
     return max_rating, min_rating, avg_rating

# %%
max_rating, min_rating, avg_rating = calculate_rating_stats(data)
print("All records: Min rating {}, Max rating = {}, Avg rating = {}".format(min_rating,max_rating,avg_rating))

max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Bollywood")
print(f"Bollywood: Min rating = {min_rating}, Max rating = {max_rating}, Avg rating = {avg_rating}")

max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Hollywood")
print(f"Hollywood: Min rating = {min_rating}, Max rating = {max_rating}, Avg rating = {avg_rating}")
# Out:
# All records: Min rating 1.9, Max rating = 9.3, Avg rating = 7.919444444444445
# Bollywood: Min rating = 1.9, Max rating = 8.4, Avg rating = 7.656250000000001
# Hollywood: Min rating = 6.8, Max rating = 9.3, Avg rating = 8.130000000000003

# %% [markdown]
# **Using Pandas**

# %%
import pandas as pd
df= pd.read_csv("/content/sample_data/movies.csv")
df.head(3)
df.tail(3)
df.sample(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9d6fead7c9b5> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df= pd.read_csv("/content/sample_data/movies.csv")
#       3 df.head(3)
#       4 df.tail(3)
#       5 df.sample(3)
#
# ...

# %%
df.shape
# Out:
# (37, 10)

# %%
df["industry"]
# Out:
# 0     Bollywood
# 1     Hollywood
# 2     Hollywood
# 3     Hollywood
# 4     Hollywood
# 5     Hollywood
# 6     Hollywood
# 7     Hollywood
# 8     Hollywood
# 9     Hollywood
# 10    Hollywood
# 11    Hollywood
# 12    Hollywood
# 13    Hollywood
# 14    Hollywood
# 15    Hollywood
# 16    Hollywood
# 17    Hollywood
# 18    Hollywood
# 19    Hollywood
# 20    Hollywood
# 21    Bollywood
# 22    Bollywood
# 23    Bollywood
# 24    Bollywood
# 25    Bollywood
# 26    Bollywood
# 27    Bollywood
# 28    Bollywood
# 29    Bollywood
# 30    Bollywood
# 31    Bollywood
# 32    Bollywood
# 33    Bollywood
# 34    Bollywood
# 35    Bollywood
# 36    Bollywood
# Name: industry, dtype: object

# %%
df.industry
# Out:
# 0     Bollywood
# 1     Hollywood
# 2     Hollywood
# 3     Hollywood
# 4     Hollywood
# 5     Hollywood
# 6     Hollywood
# 7     Hollywood
# 8     Hollywood
# 9     Hollywood
# 10    Hollywood
# 11    Hollywood
# 12    Hollywood
# 13    Hollywood
# 14    Hollywood
# 15    Hollywood
# 16    Hollywood
# 17    Hollywood
# 18    Hollywood
# 19    Hollywood
# 20    Hollywood
# 21    Bollywood
# 22    Bollywood
# 23    Bollywood
# 24    Bollywood
# 25    Bollywood
# 26    Bollywood
# 27    Bollywood
# 28    Bollywood
# 29    Bollywood
# 30    Bollywood
# 31    Bollywood
# 32    Bollywood
# 33    Bollywood
# 34    Bollywood
# 35    Bollywood
# 36    Bollywood
# Name: industry, dtype: object

# %%
dir(df.industry)
df
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df_b=df[df.industry=="Bollywood"]
df_b.imdb_rating.min()
# Out:
# 1.9

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.imdb_rating.min()
# Out:
# 1.9

# %%
df[df.studio=="Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df[2:5]
# Out:
#                      title   industry  release_year  imdb_rating  \
# 2    Thor: The Dark World   Hollywood          2013          6.8
# 3          Thor: Ragnarok   Hollywood          2017          7.9
# 4  Thor: Love and Thunder   Hollywood          2022          6.8
#
#            studio  budget  revenue      unit currency language
# 2  Marvel Studios   165.0    644.8  Millions      USD  English
# 3  Marvel Studios   180.0    854.0  Millions      USD  English
# 4  Marvel Studios   250.0    670.0  Millions      USD  English

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df[(df.release_year>=2000)]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 11                                       Avatar  Hollywood          2009
# 13                              The Dark Knight  Hollywood          2008
# 16                                     Parasite  Hollywood          2019
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.iloc[2:5]
# Out:
#                      title   industry  release_year  imdb_rating  \
# 2    Thor: The Dark World   Hollywood          2013          6.8
# 3          Thor: Ragnarok   Hollywood          2017          7.9
# 4  Thor: Love and Thunder   Hollywood          2022          6.8
#
#            studio  budget  revenue      unit currency language
# 2  Marvel Studios   165.0    644.8  Millions      USD  English
# 3  Marvel Studios   180.0    854.0  Millions      USD  English
# 4  Marvel Studios   250.0    670.0  Millions      USD  English

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv")
df1
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
# 5                       TATA            5.6         -1       n.a.
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani
# 5     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",skiprows=1)
df1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1)
df1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1,names=["stock_symbol"])
df1
# Out:
#                                 stock_symbol
# GOOGL 27.82          87  845      larry page
# WMT   4.61           484 65             n.a.
# MSFT  -1             85  64       bill gates
# RIL   not available  50  1023  mukesh ambani
# TATA  5.6           -1   n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1,names=["stock_symbol","eps","revenue","price","people"])
df1
# Out:
#   stock_symbol            eps  revenue price         people
# 0        GOOGL          27.82       87   845     larry page
# 1          WMT           4.61      484    65           n.a.
# 2         MSFT             -1       85    64     bill gates
# 3         RIL   not available       50  1023  mukesh ambani
# 4         TATA            5.6       -1  n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1,nrows=2)
df1
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1)
df1.head(2)
# Out:
#   tickers    eps  revenue price      people
# 0   GOOGL  27.82       87   845  larry page
# 1     WMT   4.61      484    65        n.a.

# %%
df1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1,na_values={"eps":["not available","-1"],"revenue":["-1"]})
df1
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65           n.a.
# 2    MSFT    NaN     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df1=pd.read_csv("/content/sample_data/stock_data.csv",header=1,na_values=["not available","-1","n.a."])
df1
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df1["pe"]=df1["price"]/ df1["eps"]
df1
# Out:
#   tickers    eps  revenue   price         people         pe
# 0   GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1     WMT   4.61    484.0    65.0            NaN  14.099783
# 2    MSFT    NaN     85.0    64.0     bill gates        NaN
# 3    RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4    TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df1.to_csv("pe.csv",index=False)
df1
# Out:
#   tickers    eps  revenue   price         people         pe
# 0   GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1     WMT   4.61    484.0    65.0            NaN  14.099783
# 2    MSFT    NaN     85.0    64.0     bill gates        NaN
# 3    RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4    TATA   5.60      NaN     NaN     ratan tata        NaN

# %% [markdown]
# **Reading excel files**

# %%
df_movies=pd.read_excel("/content/sample_data/movies_db.xlsx","movies")
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_finance=pd.read_excel("/content/sample_data/movies_db.xlsx","financials")
df_finance
# Out:
#     movie_id    budget   revenue       unit currency
# 0        101      1.00      12.5   Billions      INR
# 1        102    200.00     954.8   Millions      USD
# 2        103    165.00     644.8   Millions       $$
# 3        104    180.00     854.0   Millions  Dollars
# 4        105    250.00     670.0   Millions      USD
# 5        107    400.00    2000.0   Millions      INR
# 6        108    550.00    4000.0   Millions      INR
# 7        109    390.00    1360.0   Millions      INR
# 8        110      1.40       3.5   Billions      INR
# 9        111     25.00      73.3   Millions      USD
# 10       113    165.00     701.8   Millions      USD
# 11       114    205.00     365.3   Millions      USD
# 12       115     55.00     307.1   Millions      USD
# 13       116    103.00     460.5   Millions      USD
# 14       117    200.00    2202.0   Millions      USD
# 15       118      3.18       3.3   Millions      USD
# 16       119    237.00    2847.0   Millions      USD
# ...

# %% [markdown]
# **Exercises**

# %%
df=pd.read_csv("/content/sample_data/movies_data.csv")
df
# Out:
#     movie_id                                        title   industry language  \
# 0        101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 5        111                     The Shawshank Redemption  Hollywood  English
# 6        113                                 Interstellar  Hollywood  English
# 7        115                     The Pursuit of Happyness  Hollywood  English
# 8        116                                    Gladiator  Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 10       118                        It's a Wonderful Life  Hollywood  English
# ...

# %%
df.head()
# Out:
#    movie_id                                        title   industry language  \
# 0       101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2       103                        Thor: The Dark World   Hollywood  English
# 3       104                              Thor: Ragnarok   Hollywood  English
# 4       105                      Thor: Love and Thunder   Hollywood  English
#
#    release_year  imdb_rating          studio  budget  revenue      unit  \
# 0          2022          8.4   Hombale Films     1.0     12.5  Billions
# 1          2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2          2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3          2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4          2022          6.8  Marvel Studios   250.0    670.0  Millions
#
#   currency
# 0      INR
# 1      USD
# 2      USD
# 3      USD
# ...

# %%
def release_year(value):
  if value<=2000:
    return "before_2000"
  elif value >=2000:
    return "from_2000"
df=pd.read_csv("/content/sample_data/movies_data.csv")

df['release_period'] = df['release_year'].apply(release_year)
print(df.head())
# Out:
#    movie_id                                        title   industry language  \
# 0       101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2       103                        Thor: The Dark World   Hollywood  English
# 3       104                              Thor: Ragnarok   Hollywood  English
# 4       105                      Thor: Love and Thunder   Hollywood  English
#
#    release_year  imdb_rating          studio  budget  revenue      unit  \
# 0          2022          8.4   Hombale Films     1.0     12.5  Billions
# 1          2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2          2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3          2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4          2022          6.8  Marvel Studios   250.0    670.0  Millions
#
#   currency release_period
# 0      INR      from_2000
# ...

# %%
df['year_classify']= df.apply(lambda x: "before 2000" if x["release_year"] <2000 else "after 2000",axis =1 )
df.head()
# Out:
#    movie_id                                        title   industry language  \
# 0       101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2       103                        Thor: The Dark World   Hollywood  English
# 3       104                              Thor: Ragnarok   Hollywood  English
# 4       105                      Thor: Love and Thunder   Hollywood  English
#
#    release_year  imdb_rating          studio  budget  revenue      unit  \
# 0          2022          8.4   Hombale Films     1.0     12.5  Billions
# 1          2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2          2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3          2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4          2022          6.8  Marvel Studios   250.0    670.0  Millions
#
#   currency release_period year_classify
# ...

# %%
df_filter=df[['movie_id', 'title', 'budget', 'revenue','year_classify']]
df_filter.to_csv("filtered.csv",index=False)

# %% [markdown]
# handling missing data

# %%
import pandas as pd

df=pd.read_csv("/content/sample_data/weather_data.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.1        8.1  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
type(df.day[0])
# Out:
# str

# %%
df=pd.read_csv("/content/sample_data/weather_data.csv",parse_dates=["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index("day",inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df=pd.read_csv("/content/sample_data/fruits_data.csv")
df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 2  01-03-2022       259.0              NaN          NaN         NaN
# 3  01-04-2022         NaN             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0          NaN       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 6  01-07-2022         NaN              NaN         70.0       174.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0         NaN
# 9  01-10-2022       240.0             48.0          NaN       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 2             93.0
# 3             74.0
# 4             84.0
# 5             93.0
# 6              NaN
# 7             86.0
# 8             93.0
# ...

# %%
df.shape
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['date', 'apple(1kg)', 'banana(1 dozen)', 'grapes(1kg)', 'mango(1kg)',
#        'Water Melons(1)'],
#       dtype='object')

# %%
df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 2  01-03-2022       259.0              NaN          NaN         NaN
# 3  01-04-2022         NaN             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0          NaN       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 6  01-07-2022         NaN              NaN         70.0       174.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0         NaN
# 9  01-10-2022       240.0             48.0          NaN       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 2             93.0
# 3             74.0
# 4             84.0
# 5             93.0
# 6              NaN
# 7             86.0
# 8             93.0
# ...

# %%
new_df = df.fillna('-1')
new_df
# Out:
#          date apple(1kg) banana(1 dozen) grapes(1kg) mango(1kg)  \
# 0  01-01-2022      230.0            46.0        65.0      184.0
# 1  01-02-2022      237.0            50.0        72.0      173.0
# 2  01-03-2022      259.0              -1          -1         -1
# 3  01-04-2022         -1            41.0        75.0      175.0
# 4  01-05-2022      240.0            48.0          -1      185.0
# 5  01-06-2022      234.0            45.0        66.0      194.0
# 6  01-07-2022         -1              -1        70.0      174.0
# 7  01-08-2022      236.0            46.0        66.0      187.0
# 8  01-09-2022      232.0            41.0        71.0         -1
# 9  01-10-2022      240.0            48.0          -1      198.0
#
#   Water Melons(1)
# 0              -1
# 1            72.0
# 2            93.0
# 3            74.0
# 4            84.0
# 5            93.0
# 6              -1
# 7            86.0
# 8            93.0
# 9            97.0

# %%
# Out:
#          date apple(1kg) banana(1 dozen) grapes(1kg) mango(1kg)  \
# 0  01-01-2022      230.0            46.0        65.0      184.0
# 1  01-02-2022      237.0            50.0        72.0      173.0
# 2  01-03-2022      259.0              -1          -1         -1
# 3  01-04-2022         -1            41.0        75.0      175.0
# 4  01-05-2022      240.0            48.0          -1      185.0
# 5  01-06-2022      234.0            45.0        66.0      194.0
# 6  01-07-2022         -1              -1        70.0      174.0
# 7  01-08-2022      236.0            46.0        66.0      187.0
# 8  01-09-2022      232.0            41.0        71.0         -1
# 9  01-10-2022      240.0            48.0          -1      198.0
#
#   Water Melons(1)
# 0              -1
# 1            72.0
# 2            93.0
# 3            74.0
# 4            84.0
# 5            93.0
# 6              -1
# 7            86.0
# 8            93.0
# 9            97.0

# %%
new_df = df.fillna({
 'apple(1kg)': df['apple(1kg)'].mean(),
 'banana(1 dozen)': df['banana(1 dozen)'].mean(),
 'grapes(1kg)': df['grapes(1kg)'].median(),
 'mango(1kg)': df['mango(1kg)'].median(),
 'Water Melons(1)': "Not Available",

 })
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0           46.000         65.0       184.0
# 1  01-02-2022       237.0           50.000         72.0       173.0
# 2  01-03-2022       259.0           45.625         70.0       184.5
# 3  01-04-2022       238.5           41.000         75.0       175.0
# 4  01-05-2022       240.0           48.000         70.0       185.0
# 5  01-06-2022       234.0           45.000         66.0       194.0
# 6  01-07-2022       238.5           45.625         70.0       174.0
# 7  01-08-2022       236.0           46.000         66.0       187.0
# 8  01-09-2022       232.0           41.000         71.0       184.5
# 9  01-10-2022       240.0           48.000         70.0       198.0
#
#   Water Melons(1)
# 0   Not Available
# 1            72.0
# 2            93.0
# 3            74.0
# 4            84.0
# 5            93.0
# 6   Not Available
# 7            86.0
# 8            93.0
# 9            97.0

# %%
n_df = df.fillna(method="ffill")
n_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 2  01-03-2022       259.0             50.0         72.0       173.0
# 3  01-04-2022       259.0             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0         75.0       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 6  01-07-2022       234.0             45.0         70.0       174.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0       187.0
# 9  01-10-2022       240.0             48.0         71.0       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 2             93.0
# 3             74.0
# 4             84.0
# 5             93.0
# 6             93.0
# 7             86.0
# 8             93.0
# ...

# %%
df.dropna(thresh=4)
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 3  01-04-2022         NaN             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0          NaN       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0         NaN
# 9  01-10-2022       240.0             48.0          NaN       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 3             74.0
# 4             84.0
# 5             93.0
# 7             86.0
# 8             93.0
# 9             97.0

# %%
new_df=df.dropna()
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
#
#    Water Melons(1)
# 1             72.0
# 5             93.0
# 7             86.0

# %%
new_df.to_csv("final_data.csv",index=False)

# %%
df=pd.read_csv("/content/sample_data/food_db.csv")
df
# Out:
#    food_id            name discount   price     rating
# 0        1  Butter Chicken      10%  $12.99  Excellent
# 1        2     Masala Dosa       5%   $7.50       Good
# 2        3         Biryani      15%  $15.99  Excellent
# 3        4           Chaat      20%   $3.99    Average
# 4        5         Samosas      10%   $2.50       Good
# 5        6   Chole Bhature       5%   $8.99  Excellent
# 6        7    Paneer Tikka      10%  $10.99  Very Good
# 7        8     Idli-Sambar      15%   $6.99       Good
# 8        9      Rogan Josh      10%  $16.99  Excellent
# 9       10           Lassi       5%   $3.50    Average

# %%
new_df = df.replace(['5%', '10%'], '13%')
new_df
# Out:
#    food_id            name discount   price     rating
# 0        1  Butter Chicken      13%  $12.99  Excellent
# 1        2     Masala Dosa      13%   $7.50       Good
# 2        3         Biryani      15%  $15.99  Excellent
# 3        4           Chaat      20%   $3.99    Average
# 4        5         Samosas      13%   $2.50       Good
# 5        6   Chole Bhature      13%   $8.99  Excellent
# 6        7    Paneer Tikka      13%  $10.99  Very Good
# 7        8     Idli-Sambar      15%   $6.99       Good
# 8        9      Rogan Josh      13%  $16.99  Excellent
# 9       10           Lassi      13%   $3.50    Average

# %%
n_df = df.replace(['Excellent', 'Very Good', 'Good', 'Average'],[1,2,3,4])
# new_df = df.replace([],
# [4,3,2,1])
n_df
# Out:
#    food_id            name discount   price  rating
# 0        1  Butter Chicken      10%  $12.99       1
# 1        2     Masala Dosa       5%   $7.50       3
# 2        3         Biryani      15%  $15.99       1
# 3        4           Chaat      20%   $3.99       4
# 4        5         Samosas      10%   $2.50       3
# 5        6   Chole Bhature       5%   $8.99       1
# 6        7    Paneer Tikka      10%  $10.99       2
# 7        8     Idli-Sambar      15%   $6.99       3
# 8        9      Rogan Josh      10%  $16.99       1
# 9       10           Lassi       5%   $3.50       4

# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/movies_data.csv")
df
# Out:
#     movie_id                                        title   industry language  \
# 0        101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 5        111                     The Shawshank Redemption  Hollywood  English
# 6        113                                 Interstellar  Hollywood  English
# 7        115                     The Pursuit of Happyness  Hollywood  English
# 8        116                                    Gladiator  Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 10       118                        It's a Wonderful Life  Hollywood  English
# ...

# %%
g=df.groupby("industry")
g

# %%
g.size()
# Out:
# industry
# Bollywood    17
# Hollywood    20
# dtype: int64

# %%
g.get_group("Bollywood")
# Out:
#     movie_id                        title   industry language  release_year  \
# 0        101             K.G.F: Chapter 2  Bollywood  Kannada          2022
# 21       107  Dilwale Dulhania Le Jayenge  Bollywood    Hindi          1995
# 22       108                     3 Idiots  Bollywood    Hindi          2009
# 23       109     Kabhi Khushi Kabhie Gham  Bollywood    Hindi          2001
# 24       110             Bajirao Mastani   Bollywood    Hindi          2015
# 25       128             Taare Zameen Par  Bollywood    Hindi          2007
# 26       129          Munna Bhai M.B.B.S.  Bollywood    Hindi          2003
# 27       130                           PK  Bollywood    Hindi          2014
# 28       131                        Sanju  Bollywood    Hindi          2018
# 29       135            The Kashmir Files  Bollywood    Hindi          2022
# 30       136            Bajrangi Bhaijaan  Bollywood    Hindi          2015
# ...

# %%
def grouper(df,idx,col):
  if 1<=df[col].loc[idx]<=3.9:
    return "Poor"
  elif 4 <= df[col].loc[idx] <= 7.9:
    return "Average"
  elif 8 <=df[col].loc[idx]<= 10:
    return "Good"
  else:
    return "others"

# %%
g=df.groupby(lambda idx:grouper(df,idx,"imdb_rating"))
g

# %%
for key,d in g:
  print("key",key)
  print("data",d)
# Out:
# key Average
# data     movie_id                                        title   industry language  \
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 11       119                                       Avatar  Hollywood  English
# 19       137           Captain America: The First Avenger  Hollywood  English
# 20       138          Captain America: The Winter Soldier  Hollywood  English
# 23       109                     Kabhi Khushi Kabhie Gham  Bollywood    Hindi
# 24       110                             Bajirao Mastani   Bollywood    Hindi
# 34       132                    Pushpa: The Rise - Part 1  Bollywood   Telugu
#
# ...
